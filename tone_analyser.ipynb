# %% [markdown]
# https://cloud.ibm.com/apidocs/tone-analyzer?code=python

# %%
import pandas as pd
from ibm_watson import ToneAnalyzerV3
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator
from ibm_watson import ApiException
import json
import re
import os

# %% [markdown]
# ### Enter API keys
#
# This is the "lazy" way to do it, if you're not going to share your code with anyone else. Otherwise consider loading from JSON below.

# %%
apikey = ''

# %%
api_url = ''

# %% [markdown]
# ### Read keys from JSON
#
# Standard code chunk to protect keys (remember to exclude json files in git)

# %%
try:
    with open('keys.json') as json_file:
        keys = json.load(json_file)
        apikey = keys['apikey']
        api_url = keys['api_url']
except:
    print('is there a json key file?')

# %%
authenticator = IAMAuthenticator(apikey)

tone_analyzer = ToneAnalyzerV3(
    version='2017-09-21',
    authenticator=authenticator
)

tone_analyzer.set_service_url(api_url)

# %%
def analyse_tone(txt):
    try:
        tone_analysis = tone_analyzer.tone(
        {'text': txt},
        content_type='application/json').get_result()
    except ApiException as ex:
        print("Method failed with status code " + str(ex.code) + ": " + ex.message)
        
    return(tone_analysis['sentences_tone'])

# %%
# rows list initialization 
def build_frame(tone, i):
    rows = [] 

    # appending rows 
    for data in tone: 
        data_row = data['tones'] 
        sentence_text = data['text']
        sentence_id = data['sentence_id'] + i

        for row in data_row: 
            row['text']= sentence_text 
            row['sentence_id'] = sentence_id 
            rows.append(row) 

    # using data frame 
    return(pd.DataFrame(rows))

# %%
files = os.listdir('./txt/')

# %%
for filename in files:
    file = open('./txt/%s' % filename, 'r')
    text = []
    for line in file.readlines():
        text.append(line.strip())
    text = list(filter(None, text))   # strip empty items
    
    
    # build the dataframe    
    df_tone = pd.DataFrame()

    for i in range(0,len(text),40):
        gobbet = ' '.join(text[i:i+40])
        result = analyse_tone(gobbet)
        tempframe = build_frame(result, i)
    
    df_tone = df_tone.append(tempframe)
    df_tone = df_tone.reset_index()
    
    
    output = filename.replace('txt', 'csv')   # create output filename
    df_tone.to_csv('./csv/%s' % output,
               encoding = 'utf-8',
               index = False)

# %%
text = []

# %%
for line in file.readlines():
        text.append(line.strip())

# strip empty items
text = list(filter(None, text))

# %%
df_tone = pd.DataFrame()

for i in range(0,len(text),40):
    gobbet = " ".join(text[i:i+40])
    result = analyse_tone(gobbet)
    tempframe = build_frame(result, i)
    
    df_tone = df_tone.append(tempframe)
    
df_tone = df_tone.reset_index()

# %%
df_tone
# Out:
#     index     score     tone_id   tone_name  \
# 0       0  0.743682  analytical  Analytical
# 1       1  0.703409  analytical  Analytical
# 2       2  0.736466  analytical  Analytical
# 3       3  0.649361  analytical  Analytical
# 4       4  0.765977  analytical  Analytical
# 5       5  0.571055         joy         Joy
# 6       6  0.897416  analytical  Analytical
# 7       7  0.823864  analytical  Analytical
# 8       8  0.738413         joy         Joy
# 9       9  0.919824  analytical  Analytical
# 10     10  0.614760  analytical  Analytical
# 11     11  0.620279  analytical  Analytical
# 12     12  0.511119   tentative   Tentative
# 13     13  0.696720  analytical  Analytical
# 14     14  0.693146   tentative   Tentative
# 15     15  0.678929  analytical  Analytical
# 16     16  0.541591  analytical  Analytical
# 17     17  0.907142  analytical  Analytical
# 18     18  0.711887  analytical  Analytical
# 19     19  0.536440  analytical  Analytical
# 20     20  0.771423     sadness     Sadness
# 21     21  0.694575     sadness     Sadness
# 22     22  0.675891     sadness     Sadness
# 23     23  0.698904   tentative   Tentative
# 24     24  0.811849  analytical  Analytical
# 25     25  0.713596     sadness     Sadness
# 26     26  0.919610   tentative   Tentative
# 27     27  0.801827  analytical  Analytical
# 28     28  0.506763  analytical  Analytical
# 29     29  0.704406         joy         Joy
# 30     30  0.821913  analytical  Analytical
# 31     31  0.775384  analytical  Analytical
# 32     32  0.521342  analytical  Analytical
# 33     33  0.579436   confident   Confident
# 34     34  0.541591  analytical  Analytical
# 35     35  0.856622   tentative   Tentative
# 36     36  0.584186  analytical  Analytical
# 37     37  0.677555         joy         Joy
# 38     38  0.671070   confident   Confident
# 39     39  0.649361  analytical  Analytical
# 40     40  0.839577   tentative   Tentative
# 41     41  0.926173  analytical  Analytical
# 42     42  0.635197  analytical  Analytical
# 43     43  0.549423         joy         Joy
#
#                                                  text  sentence_id
# 0   The EU targets a reduction of CO2 emissions of...            0
# 1   This has already led to a 21% reduction in CO2...            1
# 2   In addition, Europe is in the process of estab...            3
# 3   Just 4% comes from the chemical industry, desp...            5
# 4   Of that 4%, 2.2% originates from steam and hea...            6
# 5            Electrification is part of the solution.            7
# 6            Electrification is part of the solution.            7
# 7   However, the need to store energy and mitigate...            8
# 8   Here, the unique properties of hydrogen make i...            9
# 9   For example, hydrogen: - Can be used to decarb...           10
# 10  Today, there is already a sizable amount of hy...           11
# 11  However, more than 90% of hydrogen plants use ...           13
# 12  Thus, decarbonizing existing hydrogen applicat...           14
# 13  Thus, decarbonizing existing hydrogen applicat...           14
# 14  But the far greater decarbonization opportunit...           15
# 15  But the far greater decarbonization opportunit...           15
# 16  The use of hydrogen in decarbonization efforts...           16
# 17  However, substituting existing fossil fuel-bas...           17
# 18  Otherwise, growth and competitiveness will be ...           18
# 19  While there is debate whether economies of sca...           23
# 20  The overall system shows significant end-to-en...           24
# 21  These losses occur during the generation of re...           25
# 22    Each of these steps involves conversion losses.           26
# 23  And the end-to-end efficiency becomes even wor...           27
# 24  And the end-to-end efficiency becomes even wor...           27
# 25  However, some of these conversion losses are a...           28
# 26  However, some of these conversion losses are a...           28
# 27  However, some of these conversion losses are a...           28
# 28  As of 2020, renewable hydrogen still requires ...           29
# 29  But it is important to remember that historica...           30
# 30  But it is important to remember that historica...           30
# 31  As these comments and hindsight tell us, the e...           32
# 32  The EU’s hydrogen strategy calls for an additi...           33
# 33  In addition, various countries, from France, G...           34
# 34  In addition, various countries, from France, G...           34
# 35  As of October 2020, approximately 2 GW of hydr...           36
# 36  As of October 2020, approximately 2 GW of hydr...           36
# 37  In summary, a huge opportunity is at hand: Hyd...           39
# 38  In summary, a huge opportunity is at hand: Hyd...           39
# 39  In summary, a huge opportunity is at hand: Hyd...           39
# 40  For chemical companies there are several possi...           40
# 41  However, it requires innovation to establish n...           42
# 42  To take advantage of the hydrogen opportunity,...           43
# 43  First and foremost, prioritize hydrogen as a k...           44

# %%
df_tone.to_csv("/Users/matm/Desktop/Accenture_TOV.csv",
               encoding = 'utf-8',
               index = False)

# %%
result
# Out:
# [{'sentence_id': 0,
#   'text': 'Fuel cell technologies and hydrogen energy are being commercialized in the US and abroad.',
#   'tones': []},
#  {'sentence_id': 1,
#   'text': 'Governments in Asia and the European Union, in coordination with industry, are now investing more than $2 billion every year in hydrogen as a promising energy carrier.',
#   'tones': [{'score': 0.541786, 'tone_id': 'joy', 'tone_name': 'Joy'}]},
#  {'sentence_id': 2,
#   'text': 'The US is among the leading countries in moving towards broad commercialization of fuel cells and hydrogen energy.',
#   'tones': [{'score': 0.548904,
#     'tone_id': 'analytical',
#     'tone_name': 'Analytical'}]},
#  {'sentence_id': 3,
#   'text': 'With over 7,600i fuel cell electric vehicles (FCEVs) currently on the road\xa0– more than any other country\xa0– the US is home to more than half of the global FCEV stock.ii',
#   'tones': []},
#  {'sentence_id': 4,
#   'text': 'In addition, the US is a global leader in the development of fuel cell applications that compete with incumbent technologies.',
#   'tones': [{'score': 0.819828,
#     'tone_id': 'analytical',
#     'tone_name': 'Analytical'}]},
#  {'sentence_id': 5,
#   'text': 'For example, more than 25,000 fuel cell–powered material handling products, such as forklifts, are operating in warehouses and distribution facilities across the country.',
#   'tones': [{'score': 0.949904,
#     'tone_id': 'analytical',
#     'tone_name': 'Analytical'}]},
#  {'sentence_id': 6,
#   'text': 'There are over 8,000 small-scale fuel cell systems operating across 40 states, primarily for cell phone towers and remote communications networks.',
#   'tones': []},
#  {'sentence_id': 7,
#   'text': 'In total, there are over 550 MW of installed or planned fuel cells for large-scale stationary power for backup power, critical loads, and combined heating and power applications.iii',
#   'tones': []},
#  {'sentence_id': 8,
#   'text': 'The US is home to several leading fuel cell, electrolyzer, and hydrogen component and system manufacturers as well as large multinational hydrogen companies with liquid and compressed hydrogen production and distribution equipment.',
#   'tones': [{'score': 0.753872,
#     'tone_id': 'analytical',
#     'tone_name': 'Analytical'}]},
#  {'sentence_id': 9,
#   'text': 'Hydrogen as a vehicle fuel can be used for the transport of goods and people.',
#   'tones': []},
#  {'sentence_id': 10,
#   'text': 'It can serve to store energy from nuclear and renewable sources and distribute it across sectors.',
#   'tones': []},
#  {'sentence_id': 11,
#   'text': 'Hydrogen and fuel cell technologies have great potential to provide low-carbon heat and reliable power for communities and critical facilities.',
#   'tones': []},
#  {'sentence_id': 12,
#   'text': 'Hydrogen is also a growing fuel and feedstock for industrial and agricultural processes, and much more.',
#   'tones': []},
#  {'sentence_id': 13,
#   'text': 'The smooth transition to a broader use of hydrogen can provide significant economic, social, and environmental benefits to\xa0the US.',
#   'tones': [{'score': 0.508914, 'tone_id': 'joy', 'tone_name': 'Joy'}]},
#  {'sentence_id': 14,
#   'text': 'While hydrogen has a strong technical foundation, positioning it as the energy carrier of choice and creating a vibrant, competitive hydrogen economy will also require a foundation of financial and policy support.',
#   'tones': [{'score': 0.512145, 'tone_id': 'joy', 'tone_name': 'Joy'},
#    {'score': 0.762356, 'tone_id': 'analytical', 'tone_name': 'Analytical'}]},
#  {'sentence_id': 15,
#   'text': 'This US Hydrogen Road Map was created through the collaboration of executives and technical industry experts in hydrogen across a broad range of applications and sectors, who are committed to improving the understanding of hydrogen and how to increase its adoption across many sectors of the economy.',
#   'tones': []},
#  {'sentence_id': 16,
#   'text': 'For the first time, this coalition of industry leaders has convened to develop a targeted, holistic approach for expanding the use of hydrogen as an energy carrier.',
#   'tones': []},
#  {'sentence_id': 17,
#   'text': 'Due to great variation among national and state policies, infrastructure needs, and community interests, each state and region of the US will likely have its own specific policies and road maps for implementing hydrogen infrastructure.',
#   'tones': [{'score': 0.608802,
#     'tone_id': 'analytical',
#     'tone_name': 'Analytical'}]},
#  {'sentence_id': 18,
#   'text': 'The West Coast, for example, has traditionally had progressive policies on reducing transportation emissions, so it is likely that hydrogen will scale sooner for vehicles in this region, especially California.',
#   'tones': [{'score': 0.617627,
#     'tone_id': 'analytical',
#     'tone_name': 'Analytical'}]},
#  {'sentence_id': 19,
#   'text': 'Experts also acknowledge the role that hydrogen in combination with renewables can play in supplying microgrid-type power to communities with the highest risk of shut-offs during seasonal weather-related issues, such as high temperatures or wildfire-related power interruptions.',
#   'tones': [{'score': 0.559148, 'tone_id': 'sadness', 'tone_name': 'Sadness'},
#    {'score': 0.793846, 'tone_id': 'analytical', 'tone_name': 'Analytical'}]},
#  {'sentence_id': 20,
#   'text': 'Some states have emphasized the need to decarbonize the gas grid, so blending hydrogen in natural gas networks and using hydrogen as feedstock may advance more quickly in these regions.',
#   'tones': [{'score': 0.647986,
#     'tone_id': 'tentative',
#     'tone_name': 'Tentative'}]},
#  {'sentence_id': 21,
#   'text': 'Other states are interested in hydrogen as a means to address power grid issues, enable the deployment of renewables, and support competitive nuclear power.',
#   'tones': []},
#  {'sentence_id': 22,
#   'text': 'The launch of hydrogen technologies in some states or regions will help to scale hydrogen in various applications across the country, laying the foundation for energy security, grid resiliency, economic growth, and the reduction of both greenhouse gas (GHG) emissions and air pollutants.',
#   'tones': []},
#  {'sentence_id': 23,
#   'text': 'This report outlines the benefits and impact of fuel cell technologies and hydrogen as a viable solution to the energy challenges facing the US through 2030 and beyond.',
#   'tones': [{'score': 0.506763,
#     'tone_id': 'analytical',
#     'tone_name': 'Analytical'}]},
#  {'sentence_id': 24,
#   'text': 'As such, it can serve as the latest comprehensive, industry-driven, national road map to accelerate and scale up hydrogen in the economy across North America.',
#   'tones': [{'score': 0.850871,
#     'tone_id': 'analytical',
#     'tone_name': 'Analytical'}]},
#  {'sentence_id': 25,
#   'text': 'Fifty years ago, the US put the first man on the moon.',
#   'tones': [{'score': 0.500576, 'tone_id': 'joy', 'tone_name': 'Joy'}]},
#  {'sentence_id': 26,
#   'text': 'The Apollo\xa011 mission relied on a hydrogen-powered fuel cell system, which supplied electricity and water for the mission, and on liquid hydrogen as fuel to propel the rockets.',
#   'tones': []},
#  {'sentence_id': 27,
#   'text': 'Since 1969, America has remained\xa0a leader in fuel cell and hydrogen technology, commercializing a wide range of technologies that produce, deliver, store, and utilize hydrogen across applications and sectors.',
#   'tones': [{'score': 0.715667,
#     'tone_id': 'analytical',
#     'tone_name': 'Analytical'}]},
#  {'sentence_id': 28,
#   'text': 'Today, the hydrogen industry as well as the US are at a crossroads as the country’s energy future is determined.',
#   'tones': [{'score': 0.568476, 'tone_id': 'joy', 'tone_name': 'Joy'},
#    {'score': 0.8766, 'tone_id': 'analytical', 'tone_name': 'Analytical'}]},
#  {'sentence_id': 29,
#   'text': 'The energy system across the US is evolving.',
#   'tones': []},
#  {'sentence_id': 30,
#   'text': 'From power generation to transportation, new technologies are gaining share.',
#   'tones': [{'score': 0.665204, 'tone_id': 'joy', 'tone_name': 'Joy'}]},
#  {'sentence_id': 31,
#   'text': 'Companies are grappling with decarbonization, preservation of natural resources, aging infrastructure, energy storage, an evolving regulatory landscape, and new customer demands.',
#   'tones': [{'score': 0.550608, 'tone_id': 'joy', 'tone_name': 'Joy'}]},
#  {'sentence_id': 32,
#   'text': 'The resiliency and reliability of our energy system are growing concerns.',
#   'tones': [{'score': 0.542524, 'tone_id': 'joy', 'tone_name': 'Joy'}]},
#  {'sentence_id': 33,
#   'text': 'Hydrogen is key to overcoming these challenges.',
#   'tones': [{'score': 0.642439, 'tone_id': 'fear', 'tone_name': 'Fear'}]},
#  {'sentence_id': 34,
#   'text': 'Hydrogen is an energy carrier that cuts across sectors and has multiple benefits.',
#   'tones': []},
#  {'sentence_id': 35,
#   'text': 'It can be used to store energy over long periods of time and transport energy over large geographies.',
#   'tones': []},
#  {'sentence_id': 36,
#   'text': 'FCEVs, whether heavy-duty, light-duty, or material-handling vehicles, produce no tailpipe emissions, and hydrogen can be produced with near-zero carbon emitted, even on a lifecycle basis.',
#   'tones': [{'score': 0.733853,
#     'tone_id': 'tentative',
#     'tone_name': 'Tentative'},
#    {'score': 0.774376, 'tone_id': 'analytical', 'tone_name': 'Analytical'}]},
#  {'sentence_id': 37,
#   'text': 'A vibrant hydrogen industry would maintain US energy leadership and security, create jobs, significantly reduce carbon emissions, and support economic growth.',
#   'tones': [{'score': 0.711887,
#     'tone_id': 'analytical',
#     'tone_name': 'Analytical'}]},
#  {'sentence_id': 38,
#   'text': 'The time to boost support for hydrogen is now.',
#   'tones': [{'score': 0.774839, 'tone_id': 'joy', 'tone_name': 'Joy'}]},
#  {'sentence_id': 39,
#   'text': 'Decisions and investments made now will have long-term impact.',
#   'tones': [{'score': 0.842108,
#     'tone_id': 'analytical',
#     'tone_name': 'Analytical'}]},
#  {'sentence_id': 40,
#   'text': 'Moreover, many energy infrastructure decisions take a long time to implement.',
#   'tones': [{'score': 0.87766,
#     'tone_id': 'analytical',
#     'tone_name': 'Analytical'}]},
#  {'sentence_id': 41,
#   'text': 'Other countries are laying plans for hydrogen economies, and the US will need to move quickly to continue to lead in this growing industry.',
#   'tones': []},
#  {'sentence_id': 42,
#   'text': 'US Department of Energy funding for hydrogen and fuel cells has ranged from approximately $100 million to $280 million per year over\xa0the last decade, with approximately $150 million per year since 2017.iv',
#   'tones': [{'score': 0.58393,
#     'tone_id': 'tentative',
#     'tone_name': 'Tentative'}]},
#  {'sentence_id': 43,
#   'text': 'Other countries are also investing heavily in hydrogen.',
#   'tones': []},
#  {'sentence_id': 44,
#   'text': 'For example, Japan’s Ministry of Economy, Trade, and Industry has announced hydrogen funding of approximately $560 million for 2019.v',
#   'tones': [{'score': 0.525007,
#     'tone_id': 'tentative',
#     'tone_name': 'Tentative'},
#    {'score': 0.828638, 'tone_id': 'analytical', 'tone_name': 'Analytical'}]},
#  {'sentence_id': 45,
#   'text': 'China has announced hydrogen transport industry investments of more than $17 billion through 2023.',
#   'tones': []},
#  {'sentence_id': 46,
#   'text': 'In Europe, Germany’s investment includes $110 million annually to fund research laboratories to test new hydrogen technologies for industrial-scale applications.',
#   'tones': [{'score': 0.582698, 'tone_id': 'joy', 'tone_name': 'Joy'}]},
#  {'sentence_id': 47,
#   'text': 'Investment is needed to lay the groundwork for hydrogen solutions.',
#   'tones': []},
#  {'sentence_id': 48,
#   'text': 'Capital is required to build foundational hydrogen infrastructure and companies need the right incentives to invest in low-carbon hydrogen solutions.',
#   'tones': [{'score': 0.827997,
#     'tone_id': 'analytical',
#     'tone_name': 'Analytical'}]},
#  {'sentence_id': 49,
#   'text': 'Regulatory barriers and appropriate codes and standards need to be addressed to enable large-scale commercialization and a robust, reliable supply chain.',
#   'tones': []},
#  {'sentence_id': 50,
#   'text': 'Funding is required for more research, development, demonstration, and deployment for hydrogen technologies, to improve competitiveness and performance.',
#   'tones': [{'score': 0.85365,
#     'tone_id': 'analytical',
#     'tone_name': 'Analytical'}]},
#  {'sentence_id': 51,
#   'text': 'Directing capital to hydrogen is key to enabling its growth in the US.',
#   'tones': [{'score': 0.659488, 'tone_id': 'joy', 'tone_name': 'Joy'}]},
#  {'sentence_id': 52,
#   'text': 'Hydrogen is critical for a lower-carbon energy mix.',
#   'tones': []},
#  {'sentence_id': 53,
#   'text': 'It can be used broadly across several industries, including for transport, steel, ammonia, methanol, refining, in residential and commercial buildings, and in the power system.',
#   'tones': []},
#  {'sentence_id': 54,
#   'text': 'By our modeling estimates, hydrogen can help meet 14 percent of US final energy demand by 2050, the equivalent of over 2,468 TWh or 8.4 billion MMBTU per year.',
#   'tones': []},
#  {'sentence_id': 55,
#   'text': 'A competitive hydrogen industry will reinforce US energy leadership.',
#   'tones': [{'score': 0.901894,
#     'tone_id': 'analytical',
#     'tone_name': 'Analytical'}]},
#  {'sentence_id': 56,
#   'text': 'The US is now the world’s largest producer of natural gas and oil, exporting to more than 35 countries.',
#   'tones': [{'score': 0.572397,
#     'tone_id': 'analytical',
#     'tone_name': 'Analytical'}]},
#  {'sentence_id': 57,
#   'text': 'As countries around the world look to hydrogen to reduce carbon emissions, the US has\xa0an opportunity to reinforce and grow its energy leadership position and create jobs in this field.',
#   'tones': [{'score': 0.69511, 'tone_id': 'joy', 'tone_name': 'Joy'},
#    {'score': 0.607667, 'tone_id': 'analytical', 'tone_name': 'Analytical'}]},
#  {'sentence_id': 58,
#   'text': 'The competitive domestic supply of hydrogen will enable exports of the fuel to other markets that do not have such competitive supplies.',
#   'tones': []},
#  {'sentence_id': 59,
#   'text': 'A robust hydrogen industry will strengthen the US economy.',
#   'tones': []},
#  {'sentence_id': 60,
#   'text': 'This growing industry creates jobs\xa0for US citizens and revenues for US businesses.',
#   'tones': []},
#  {'sentence_id': 61,
#   'text': 'These businesses operating in the hydrogen value chain will also grow by exporting technology to regions looking to develop their hydrogen infrastructure, such as Europe, China, Japan, Korea, and Australia.',
#   'tones': [{'score': 0.727113,
#     'tone_id': 'analytical',
#     'tone_name': 'Analytical'}]},
#  {'sentence_id': 62,
#   'text': 'By 2030, the hydrogen economy in the US could generate an estimated $140 billion per year in revenue and support 700,000 total jobs across the hydrogen value chain.',
#   'tones': [{'score': 0.546148,
#     'tone_id': 'analytical',
#     'tone_name': 'Analytical'}]},
#  {'sentence_id': 63,
#   'text': 'By 2050, it could drive growth by generating about $750 billion per year in revenue and a cumulative 3.4 million jobs (Exhibit\xa01).',
#   'tones': [{'score': 0.615352,
#     'tone_id': 'tentative',
#     'tone_name': 'Tentative'}]},
#  {'sentence_id': 64,
#   'text': 'By utilizing domestic energy resources and increasing energy resiliency, hydrogen will help to preserve our national energy security.',
#   'tones': []},
#  {'sentence_id': 65,
#   'text': 'Hydrogen production would use abundant renewable resources, natural gas, and carbon storage, and enable a competitive nuclear industry.',
#   'tones': [{'score': 0.656175,
#     'tone_id': 'analytical',
#     'tone_name': 'Analytical'}]},
#  {'sentence_id': 66,
#   'text': 'Long-term energy storage with hydrogen will maximize renewable energy production and use, further enhancing total domestic energy production and use.',
#   'tones': [{'score': 0.687768,
#     'tone_id': 'analytical',
#     'tone_name': 'Analytical'}]},
#  {'sentence_id': 67,
#   'text': 'It would allow abundant domestic natural gas to continue to provide affordable energy to meet demand, even in a decarbonized scenario, with the application of carbon capture.',
#   'tones': [{'score': 0.584186,
#     'tone_id': 'analytical',
#     'tone_name': 'Analytical'}]},
#  {'sentence_id': 68,
#   'text': 'Hydrogen has significant environmental and health benefits.',
#   'tones': [{'score': 0.669675, 'tone_id': 'joy', 'tone_name': 'Joy'}]},
#  {'sentence_id': 69,
#   'text': 'Hydrogen is an especially valuable solution for energy needs in areas that are difficult to decarbonize, such as long-distance road transport and high-grade heat.',
#   'tones': [{'score': 0.860589,
#     'tone_id': 'analytical',
#     'tone_name': 'Analytical'}]},
#  {'sentence_id': 70,
#   'text': 'Besides lower carbon emissions, hydrogen used as vehicle fuel completely eliminates emissions of tailpipe particulates, nitrogen oxides (NOx), and sulfur oxides (SOx), improving regional air quality while reducing greenhouse gas emissions (GHG) emissions.',
#   'tones': []},
#  {'sentence_id': 71,
#   'text': 'Hydrogen enables better integration of low-carbon electric power resources.',
#   'tones': []},
#  {'sentence_id': 72,
#   'text': 'Grid-connected electrolyzers that produce hydrogen could provide a significant source of flexibility for intermittent renewables, providing long-duration storage solutions that are complementary to short-duration battery solutions.',
#   'tones': [{'score': 0.73677,
#     'tone_id': 'analytical',
#     'tone_name': 'Analytical'}]},
#  {'sentence_id': 73,
#   'text': 'In addition, they can provide additional load for low-carbon power sources like renewable and nuclear power.',
#   'tones': [{'score': 0.72085,
#     'tone_id': 'analytical',
#     'tone_name': 'Analytical'}]},
#  {'sentence_id': 74,
#   'text': 'Hydrogen is a unique energy carrier with applications across sectors Hydrogen can be used: In buildings.',
#   'tones': []},
#  {'sentence_id': 75,
#   'text': 'An estimated 47 percent of US homes currently have natural gas space heating, and another 3 to 8 percent (depending on region) use liquified petroleum gas (LPG) heating.viii',
#   'tones': [{'score': 0.515711,
#     'tone_id': 'tentative',
#     'tone_name': 'Tentative'},
#    {'score': 0.583856, 'tone_id': 'analytical', 'tone_name': 'Analytical'}]},
#  {'sentence_id': 76,
#   'text': 'Replacing or blending some natural gas with low-carbon hydrogen would lower GHG emissions of residential, commercial, and industrial heating, without new infrastructure deployment.',
#   'tones': [{'score': 0.769251,
#     'tone_id': 'tentative',
#     'tone_name': 'Tentative'}]},
#  {'sentence_id': 77,
#   'text': 'This can be achieved by blending hydrogen into the natural gas grid or deploying stationary fuel cells directly in buildings to generate electricity and use the heat they produce in lieu of traditional space and water heaters.',
#   'tones': [{'score': 0.697195,
#     'tone_id': 'analytical',
#     'tone_name': 'Analytical'}]},
#  {'sentence_id': 78, 'text': 'In transport.', 'tones': []},
#  {'sentence_id': 79,
#   'text': 'Transport accounts for a third of US carbon emissionsix and directly affects air quality in cities. FCEVs and battery-electric vehicles (BEVs) are the only zero-emissions vehicle (ZEV) solutions to reduce emissions for light-duty, heavy-duty, and material-handling vehicles.',
#   'tones': []},
#  {'sentence_id': 80,
#   'text': 'With fueling times similar to conventional gasoline or diesel vehicles, and with larger on-board energy storage capacity than BEVs, FCEVs are a natural complementary ZEV technology for the transport sector to transition to zero carbon.',
#   'tones': []},
#  {'sentence_id': 81,
#   'text': 'This makes light-duty and heavy-duty FCEVs a familiar and competitive mobility solution for customers who want the capability to refuel quickly, drive long distances, carry heavy loads, or have high uptime.',
#   'tones': []},
#  {'sentence_id': 82,
#   'text': 'On a total cost of ownership (TCO) basis, FCEVs could break even between 2025 and 2030 with the cost of internal combustion engine (ICE) vehicles in applications requiring high uptime and fast fueling, and they already cost less than BEVs as forklifts and in fast charge applications above 60 kW.',
#   'tones': []},
#  {'sentence_id': 83, 'text': 'In industrial processes.', 'tones': []},
#  {'sentence_id': 84,
#   'text': 'Industry accounts for about 20 percent of US carbon emissions.x',
#   'tones': []},
#  {'sentence_id': 85,
#   'text': 'The hard-to-decarbonize industrial sectors can use low-carbon hydrogen as feedstock in industrial processes such as steelmaking, chemical production, and refining, or\xa0as\xa0a heating source to replace fossil fuels.',
#   'tones': [{'score': 0.821444,
#     'tone_id': 'analytical',
#     'tone_name': 'Analytical'}]},
#  {'sentence_id': 86,
#   'text': 'In steelmaking, for example, hydrogen can work as a reductant, substituting coal or natural gas.',
#   'tones': [{'score': 0.681699,
#     'tone_id': 'tentative',
#     'tone_name': 'Tentative'},
#    {'score': 0.916468, 'tone_id': 'analytical', 'tone_name': 'Analytical'}]},
#  {'sentence_id': 87,
#   'text': 'Other heavy industrial sectors like ammonia, methanol, and refining already use large quantities of traditional hydrogen (synthesized from natural gas) and would need to transition to low-carbon hydrogen to reduce their emissions.',
#   'tones': []},
#  {'sentence_id': 88,
#   'text': 'As backup power or off-grid power.',
#   'tones': [{'score': 0.946222,
#     'tone_id': 'tentative',
#     'tone_name': 'Tentative'}]},
#  {'sentence_id': 89,
#   'text': 'Through stationary fuel cells, hydrogen provides clean, noiseless, and odorless power.',
#   'tones': []},
#  {'sentence_id': 90,
#   'text': 'It provides backup power for data centers, hospitals, and other critical infrastructure, as well as off-grid power on military bases and in other remote facilities with fast ramp-up or ramp-down capabilities.',
#   'tones': [{'score': 0.546148,
#     'tone_id': 'analytical',
#     'tone_name': 'Analytical'}]},
#  {'sentence_id': 91,
#   'text': 'The use of hydrogen fuel cells instead of diesel generators in data centers appears on track to achieve cost parity in three to five years and has additional advantages, such as reduced clean-air permit constraints and increased operational flexibility.xi',
#   'tones': [{'score': 0.851087,
#     'tone_id': 'analytical',
#     'tone_name': 'Analytical'}]},
#  {'sentence_id': 92,
#   'text': 'It also has the potential to offer services back to the electric grid in the forms of energy storage and peaking capacity.',
#   'tones': []},
#  {'sentence_id': 93, 'text': 'In the power system.', 'tones': []},
#  {'sentence_id': 94,
#   'text': 'Grid-connected hydrogen production could support the deployment of variable renewables, by providing demand flexibility to the system.',
#   'tones': [{'score': 0.873263,
#     'tone_id': 'tentative',
#     'tone_name': 'Tentative'},
#    {'score': 0.615741, 'tone_id': 'analytical', 'tone_name': 'Analytical'}]},
#  {'sentence_id': 95,
#   'text': 'Electrolyzers have the ability to flex up and down to help match the variable and intermittent supply profile of wind or solar energy.',
#   'tones': [{'score': 0.591079, 'tone_id': 'joy', 'tone_name': 'Joy'},
#    {'score': 0.769251, 'tone_id': 'tentative', 'tone_name': 'Tentative'}]},
#  {'sentence_id': 96,
#   'text': 'This improves the case for renewables, as it partially offsets the intermittency problems on the supply side.',
#   'tones': [{'score': 0.677069,
#     'tone_id': 'analytical',
#     'tone_name': 'Analytical'}]},
#  {'sentence_id': 97,
#   'text': 'Where required, stored hydrogen can also be converted back into power via fuel cells or using hydrogen-ready gas turbines (at a new or retrofitted power station).',
#   'tones': [{'score': 0.716301,
#     'tone_id': 'tentative',
#     'tone_name': 'Tentative'},
#    {'score': 0.67368, 'tone_id': 'analytical', 'tone_name': 'Analytical'}]},
#  {'sentence_id': 98,
#   'text': 'In this way, hydrogen can provide a long-term, high-capacity electricity storage mechanism.',
#   'tones': []},
#  {'sentence_id': 99,
#   'text': 'In the ambitious scenario, hydrogen demand potential across all these applications could reach 17 million metric tons by 2030 and 63 million metric tons by 2050.',
#   'tones': []}]
