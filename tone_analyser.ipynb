# %% [markdown]
# # Background
#
# We're using [IBM Watson's Tone Analyser API](https://cloud.ibm.com/apidocs/tone-analyzer?code=python) to score sentences for emotion.
#
# The text for this analysis was extracted from multiple PDF reports.

# %%
import pandas as pd
from ibm_watson import ToneAnalyzerV3
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator
from ibm_watson import ApiException
import json
import re
import os

# %% [markdown]
# ### Enter API keys
#
# This is the "lazy" way to do it, if you're not going to share your code with anyone else. Otherwise consider loading from JSON below.

# %%
apikey = ''

# %%
api_url = ''

# %% [markdown]
# ### Read keys from JSON
#
# Standard code chunk to protect keys (remember to exclude json files in git)

# %%
try:
    with open('keys.json') as json_file:
        keys = json.load(json_file)
        apikey = keys['apikey']
        api_url = keys['api_url']
except:
    print('is there a json key file?')

# %% [markdown]
# ## Authenticate with IBM Watson
#
# Standard flow from [IBM Watson documentation](https://cloud.ibm.com/apidocs/tone-analyzer?code=python#authentication)

# %%
authenticator = IAMAuthenticator(apikey)

tone_analyzer = ToneAnalyzerV3(
    version='2017-09-21',
    authenticator=authenticator
)

tone_analyzer.set_service_url(api_url)

# %% [markdown]
# ## Helper functions

# %%
def analyse_tone(txt):
    try:
        tone_analysis = tone_analyzer.tone(
        {'text': txt},
        content_type='application/json').get_result()
    except ApiException as ex:
        print("Method failed with status code " + str(ex.code) + ": " + ex.message)
        
    return(tone_analysis['sentences_tone'])

# %%
# rows list initialization 
def build_frame(tone, i):
    rows = [] 

    # appending rows 
    for data in tone: 
        data_row = data['tones'] 
        sentence_text = data['text']
        sentence_id = data['sentence_id'] + i

        for row in data_row: 
            row['text']= sentence_text 
            row['sentence_id'] = sentence_id 
            rows.append(row) 

    # using data frame 
    return(pd.DataFrame(rows))

# %% [markdown]
# ## Main loop
#
# Cycle through all the text files in the `/txt/` directory, breaking them down into gobbets for the API.

# %%
files = os.listdir('./txt/')

# %%
for filename in files:
    file = open('./txt/%s' % filename, 'r')
    text = []
    for line in file.readlines():
        text.append(line.strip())
    text = list(filter(None, text))   # strip empty items
    
    
    # build the dataframe    
    df_tone = pd.DataFrame()

    for i in range(0,len(text),40):
        gobbet = ' '.join(text[i:i+40])
        result = analyse_tone(gobbet)
        tempframe = build_frame(result, i)
    
    df_tone = df_tone.append(tempframe)
    df_tone = df_tone.reset_index()
    
    
    output = filename.replace('txt', 'csv')   # create output filename
    df_tone.to_csv('./csv/%s' % output,
               encoding = 'utf-8',
               index = False)

# %%
df_tone
# Out:
#     index     score     tone_id   tone_name  \
# 0       0  0.743682  analytical  Analytical
# 1       1  0.703409  analytical  Analytical
# 2       2  0.736466  analytical  Analytical
# 3       3  0.649361  analytical  Analytical
# 4       4  0.765977  analytical  Analytical
# 5       5  0.571055         joy         Joy
# 6       6  0.897416  analytical  Analytical
# 7       7  0.823864  analytical  Analytical
# 8       8  0.738413         joy         Joy
# 9       9  0.919824  analytical  Analytical
# 10     10  0.614760  analytical  Analytical
# 11     11  0.620279  analytical  Analytical
# 12     12  0.511119   tentative   Tentative
# 13     13  0.696720  analytical  Analytical
# 14     14  0.693146   tentative   Tentative
# 15     15  0.678929  analytical  Analytical
# 16     16  0.541591  analytical  Analytical
# 17     17  0.907142  analytical  Analytical
# 18     18  0.711887  analytical  Analytical
# 19     19  0.536440  analytical  Analytical
# 20     20  0.771423     sadness     Sadness
# 21     21  0.694575     sadness     Sadness
# 22     22  0.675891     sadness     Sadness
# 23     23  0.698904   tentative   Tentative
# 24     24  0.811849  analytical  Analytical
# 25     25  0.713596     sadness     Sadness
# 26     26  0.919610   tentative   Tentative
# 27     27  0.801827  analytical  Analytical
# 28     28  0.506763  analytical  Analytical
# 29     29  0.704406         joy         Joy
# 30     30  0.821913  analytical  Analytical
# 31     31  0.775384  analytical  Analytical
# 32     32  0.521342  analytical  Analytical
# 33     33  0.579436   confident   Confident
# 34     34  0.541591  analytical  Analytical
# 35     35  0.856622   tentative   Tentative
# 36     36  0.584186  analytical  Analytical
# 37     37  0.677555         joy         Joy
# 38     38  0.671070   confident   Confident
# 39     39  0.649361  analytical  Analytical
# 40     40  0.839577   tentative   Tentative
# 41     41  0.926173  analytical  Analytical
# 42     42  0.635197  analytical  Analytical
# 43     43  0.549423         joy         Joy
#
#                                                  text  sentence_id
# 0   The EU targets a reduction of CO2 emissions of...            0
# 1   This has already led to a 21% reduction in CO2...            1
# 2   In addition, Europe is in the process of estab...            3
# 3   Just 4% comes from the chemical industry, desp...            5
# 4   Of that 4%, 2.2% originates from steam and hea...            6
# 5            Electrification is part of the solution.            7
# 6            Electrification is part of the solution.            7
# 7   However, the need to store energy and mitigate...            8
# 8   Here, the unique properties of hydrogen make i...            9
# 9   For example, hydrogen: - Can be used to decarb...           10
# 10  Today, there is already a sizable amount of hy...           11
# 11  However, more than 90% of hydrogen plants use ...           13
# 12  Thus, decarbonizing existing hydrogen applicat...           14
# 13  Thus, decarbonizing existing hydrogen applicat...           14
# 14  But the far greater decarbonization opportunit...           15
# 15  But the far greater decarbonization opportunit...           15
# 16  The use of hydrogen in decarbonization efforts...           16
# 17  However, substituting existing fossil fuel-bas...           17
# 18  Otherwise, growth and competitiveness will be ...           18
# 19  While there is debate whether economies of sca...           23
# 20  The overall system shows significant end-to-en...           24
# 21  These losses occur during the generation of re...           25
# 22    Each of these steps involves conversion losses.           26
# 23  And the end-to-end efficiency becomes even wor...           27
# 24  And the end-to-end efficiency becomes even wor...           27
# 25  However, some of these conversion losses are a...           28
# 26  However, some of these conversion losses are a...           28
# 27  However, some of these conversion losses are a...           28
# 28  As of 2020, renewable hydrogen still requires ...           29
# 29  But it is important to remember that historica...           30
# 30  But it is important to remember that historica...           30
# 31  As these comments and hindsight tell us, the e...           32
# 32  The EU’s hydrogen strategy calls for an additi...           33
# 33  In addition, various countries, from France, G...           34
# 34  In addition, various countries, from France, G...           34
# 35  As of October 2020, approximately 2 GW of hydr...           36
# 36  As of October 2020, approximately 2 GW of hydr...           36
# 37  In summary, a huge opportunity is at hand: Hyd...           39
# 38  In summary, a huge opportunity is at hand: Hyd...           39
# 39  In summary, a huge opportunity is at hand: Hyd...           39
# 40  For chemical companies there are several possi...           40
# 41  However, it requires innovation to establish n...           42
# 42  To take advantage of the hydrogen opportunity,...           43
# 43  First and foremost, prioritize hydrogen as a k...           44

# %%
df_tone.to_csv("/Users/matm/Desktop/Accenture_TOV.csv",
               encoding = 'utf-8',
               index = False)
